# %%
a = 5
b = 2
print(a/b)
print('bye')
# Out:
# 2.5
# bye

# %%
c = 5
d = 0
print(d/c)
print('bye')
# Out:
# 0.0
# bye

# %%
c = 5
d = 0
print(d/c)
print('bye')
# Out:
# 0.0
# bye

# %%
c = 5
d = 0
print(c/d)
print('bye')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 c = 5
#       2 d = 0
# ----> 3 print(c/d)
#       4 print('bye')
#
# ZeroDivisionError: division by zero

# %%
c = 3
d = 0
try:
    print(c/d) # if this code gives error then except block executes and prints message
except Exception:
    print('you cant divide num with zero')
print('bye')
# Out:
# you cant divide num with zero
# bye

# %%
c = 3
d = 0
try:
    print(c/d)
except Exception as e:
    print('you cant divide number with zero:',e)
print('bye')
# Out:
# you cant divide number with zero: division by zero
# bye

# %%
c = 3
d = 0
try:
    print(d/c)
except Exception as e:
    print('you cant divide number with zero',e)
print('bye')
# Out:
# 0.0
# bye

# %%
c = 3
d = 3
try:
    print('resource open')
    print(c/d)
    print('resource closed')
except Exception as e:
    print('you cant divide number with zero',e)
# Out:
# resource open
# 1.0
# resource closed

# %%
c = 3
d = 0
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    print('resource closed')
except Exception as e:
    print('you cant divide number with zero',e)# here resouce didnt closed as exception raised
# Out:
# resource open
# you cant divide number with zero division by zero

# %%
c = 3
d = 0
try:
    print('resource open')
    print(c/d)
except Exception as e:
    print('you cant divide number with zero',e)
    print('resource closed')
# Out:
# resource open
# you cant divide number with zero division by zero
# resource closed

# %%
c = 3
d = 3
try:
    print('resouce opened')
    print(c/d)
except Exception as e:
    print('you cant divide number with zero',e)
    print('resouce closed')
# Out:
# resouce opened
# 1.0
