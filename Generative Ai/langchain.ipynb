# %%
pip install -U langchain-google-genai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import getpass
import os
# copy the api key from google ai studio and paste in pop up box
if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = "AIzaSyC3BrJCnbaPwDx-wG60M9UOvBMAeMW0D0w"

from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

# %%
messages = model.invoke('explain about india and economy in brief')
print(messages) # chatmodel with gemini model integration
# Out:
# content='Okay, here\'s a brief overview of India and its economy:\n\n**India: A Quick Snapshot**\n\n*   **Location:** South Asia\n*   **Capital:** New Delhi\n*   **Population:** The most populous country in the world (over 1.4 billion)\n*   **Government:** Parliamentary Republic\n*   **Diversity:**  India is incredibly diverse, with many languages, religions, cultures, and ethnicities.\n*   **Strategic Importance:** India is a major geopolitical player due to its size, population, and growing economy.\n\n**The Indian Economy: Key Features**\n\n*   **Mixed Economy:** India has a mixed economy, meaning it combines elements of both capitalism and socialism.  The government plays a significant role, but the private sector is increasingly important.\n*   **Major Sectors:**\n    *   **Services:** The largest sector, contributing over 50% to GDP. Includes IT, business process outsourcing (BPO), finance, tourism, etc.\n    *   **Industry:**  Manufacturing, mining, construction.  The governme
# ...

# %%
from langchain_core.messages import HumanMessage,SystemMessage
messages = [
    SystemMessage("Translate the following English text to French."),
    HumanMessage("Hello, how are your teams working on langchain with google gemini models?")
]
model.invoke(messages) #
# Out:
# AIMessage(content='Bonjour, comment vos équipes travaillent-elles sur Langchain avec les modèles Google Gemini ?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e39eb8fe-2dcd-4ad3-9e21-a1cf4a54aa02-0', usage_metadata={'input_tokens': 24, 'output_tokens': 18, 'total_tokens': 42, 'input_token_details': {'cache_read': 0}})
