# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r'C:\Users\Tharuni\Desktop\NIT\oct month\13th_opencv\Gemini_Generated_Image_11a8c511a8c511a8.png')

# %%
input
# Out:
# array([[[152, 119,  83],
#         [151, 119,  84],
#         [151, 119,  84],
#         ...,
#         [164, 135,  96],
#         [166, 137,  99],
#         [163, 133,  97]],
#
#        [[151, 120,  85],
#         [151, 119,  85],
#         [151, 119,  84],
#         ...,
#         [162, 135,  97],
#         [165, 135, 100],
#         [164, 135,  99]],
#
#        [[152, 120,  84],
#         [151, 119,  83],
#         [151, 119,  84],
#         ...,
#         [165, 136, 100],
#         [164, 134,  98],
#         [165, 136,  99]],
#
#        ...,
#
#        [[ 48,  55,  62],
#         [ 48,  55,  63],
#         [ 48,  53,  62],
#         ...,
#         [ 65,  74,  87],
#         [ 64,  74,  86],
#         [ 65,  73,  84]],
#
#        [[ 55,  63,  72],
#         [ 56,  64,  74],
#         [ 54,  61,  71],
#         ...,
#         [ 62,  71,  83],
#         [ 63,  70,  83],
#         [ 62,  71,  81]],
#
#        [[ 57,  65,  77],
#         [ 60,  69,  80],
#         [ 60,  69,  79],
# ...

# %%
cv2.imshow('car',input) #displays in new tab
cv2.waitKey() # keep waits the opened image for infinity time 
cv2.destroyAllWindows() # when user press any key from keypad new opened window will destroy

# %%
print('height of image:',int(input.shape[0]),'pixels')
print('width of image:',int(input.shape[1]),'pixels')
# Out:
# height of image: 1024 pixels
# width of image: 1024 pixels

# %%
cv2.imwrite('output.png',input) # write the image means save the img to path
# Out:
# True

# %%
import os 
os.getcwd()
# Out:
# 'c:\\Users\\Tharuni\\Desktop\\NIT\\oct month\\13th_opencv'
